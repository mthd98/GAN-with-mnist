# %%
# %matplotlib inline
import pickle as pkl
import numpy as np 
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist=input_data.read_data_sets('MNIST_data')
# Out:
# WARNING:tensorflow:From <ipython-input-2-cf0ef24d19bc>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
def model_inputs(real_dim,z_dim):
  inputs_real=tf.placeholder(tf.float32,shape=(None,real_dim),name='inputs_real')
  inputs_z=tf.placeholder(tf.float32,(None ,z_dim),name='inputs_z')
  return inputs_real ,inputs_z

# %%
def generator(z, out_dim, n_units=128, reuse=False,  alpha=0.01):
    ''' Build the generator network.
    
        Arguments
        ---------
        z : Input tensor for the generator
        out_dim : Shape of the generator output
        n_units : Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out: 
    '''
    with tf.variable_scope('generator',reuse=reuse):
      h1 = tf.layers.dense(z,n_units,activation=None)
        # Leaky ReLU
      h1 = tf.nn.leaky_relu(h1,alpha)
      h1 = tf.layers.dense(h1,n_units,activation=None)
      h1 = tf.nn.leaky_relu(h1,alpha)
        
        # Logits and tanh output
      logits = tf.layers.dense(h1,out_dim,activation=None)
      out =tf.nn.tanh(logits)
        
      return out

# %%
def discriminator(x,n_units=128,reuse=False,alpha=0.01):
  with tf.variable_scope('discriminator',reuse=reuse):
    h1=tf.layers.dense(x,n_units,activation=None)
    h1=tf.nn.leaky_relu(h1,alpha)
    h1=tf.layers.dense(h1,n_units,activation=None)
    h1=tf.nn.leaky_relu(h1,alpha)
    logits=tf.layers.dense(h1,1,activation=None)
    out=tf.nn.sigmoid(logits)
    return out,logits

# %%
# Size of input image to discriminator
input_size = 784 # 28x28 MNIST images flattened
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 128
d_hidden_size = 128
# Leak factor for leaky ReLU
alpha = 0.01
# Label smoothing 
smooth = 0.1

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z =  model_inputs(input_size,z_size)

# Generator network here
g_model = generator(input_z,input_size,n_units=g_hidden_size,alpha=alpha)
# g_model is the generator output

# Disriminator network here
d_model_real, d_logits_real = discriminator(input_real,n_units=d_hidden_size,alpha=alpha)
d_model_fake, d_logits_fake =discriminator(g_model,reuse=True, n_units=d_hidden_size, alpha=alpha)

# %%
d_loss_real=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real,labels=tf.ones_like(d_logits_real)*(1-smooth)))
d_loss_fake=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,labels=tf.zeros_like(d_logits_real)))
d_loss=d_loss_real+d_loss_fake
g_loss=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,labels=tf.ones_like(d_logits_fake)))

# %%
learning_rate=0.002
t_vars=tf.trainable_variables()
g_vars=[var for var in t_vars if var.name.startswith('generator')]
d_vars=[var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt=tf.train.AdamOptimizer(learning_rate).minimize(d_loss,var_list=d_vars)
g_train_opt=tf.train.AdamOptimizer(learning_rate).minimize(g_loss,var_list=g_vars)

# %%
batch_size=100
epochs=200
samples=[]
losses=[]
saver=tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())
  for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
      batch=mnist.train.next_batch(batch_size)
      batch_images=batch[0].reshape((batch_size,784))
      batch_images=batch_images*2 -1
      batch_z=np.random.uniform(-1,1,size=(batch_size,z_size))
      _=sess.run(d_train_opt,feed_dict={input_real:batch_images,input_z:batch_z})
      _=sess.run(g_train_opt,feed_dict={input_z:batch_z})
    train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
    train_loss_g = g_loss.eval({input_z: batch_z})
    print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
    losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                       feed_dict={input_z: sample_z})
    samples.append(gen_samples)
    saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/200... Discriminator Loss: 0.7307... Generator Loss: 1.3322
# Epoch 2/200... Discriminator Loss: 0.4564... Generator Loss: 3.1632
# Epoch 3/200... Discriminator Loss: 0.5297... Generator Loss: 4.3255
# Epoch 4/200... Discriminator Loss: 0.7123... Generator Loss: 2.2879
# Epoch 5/200... Discriminator Loss: 0.5153... Generator Loss: 2.4878
# Epoch 6/200... Discriminator Loss: 0.8955... Generator Loss: 2.4519
# Epoch 7/200... Discriminator Loss: 0.8762... Generator Loss: 2.2527
# Epoch 8/200... Discriminator Loss: 0.7155... Generator Loss: 2.3022
# Epoch 9/200... Discriminator Loss: 0.8876... Generator Loss: 1.7902
# Epoch 10/200... Discriminator Loss: 1.0044... Generator Loss: 2.1615
# Epoch 11/200... Discriminator Loss: 0.7769... Generator Loss: 3.0942
# Epoch 12/200... Discriminator Loss: 0.8905... Generator Loss: 1.8375
# Epoch 13/200... Discriminator Loss: 0.8727... Generator Loss: 1.7558
# Epoch 14/200... Discriminator Loss: 0.6988... Generator Loss: 2.6755
# Epoch 15/200... Discriminator Loss: 0.8855... Generator Loss: 3.0150
# Epoch 16/200... Discriminator Loss: 0.6981... Generator Loss: 2.2336
# Epoch 17/200... Discriminator Loss: 0.7699... Generator Loss: 4.0950
# Epoch 18/200... Discriminator Loss: 0.6598... Generator Loss: 2.3847
# Epoch 19/200... Discriminator Loss: 0.8467... Generator Loss: 1.7652
# Epoch 20/200... Discriminator Loss: 0.8066... Generator Loss: 1.9409
# Epoch 21/200... Discriminator Loss: 0.8234... Generator Loss: 2.1762
# Epoch 22/200... Discriminator Loss: 0.8262... Generator Loss: 2.2057
# Epoch 23/200... Discriminator Loss: 0.9260... Generator Loss: 1.7718
# Epoch 24/200... Discriminator Loss: 0.8852... Generator Loss: 2.1848
# Epoch 25/200... Discriminator Loss: 0.9316... Generator Loss: 2.3095
# Epoch 26/200... Discriminator Loss: 1.0028... Generator Loss: 2.5627
# Epoch 27/200... Discriminator Loss: 0.8553... Generator Loss: 2.0655
# Epoch 28/200... Discriminator Loss: 0.8243... Generator Loss: 2.3280
# Epoch 29/200... Discriminator Loss: 0.9185... Generator Loss: 2.2069
# Epoch 30/200... Discriminator Loss: 0.9809... Generator Loss: 2.0030
# Epoch 31/200... Discriminator Loss: 0.8467... Generator Loss: 2.2210
# Epoch 32/200... Discriminator Loss: 0.9985... Generator Loss: 1.6117
# Epoch 33/200... Discriminator Loss: 0.9984... Generator Loss: 1.5682
# Epoch 34/200... Discriminator Loss: 0.9343... Generator Loss: 1.5854
# Epoch 35/200... Discriminator Loss: 0.9466... Generator Loss: 1.9299
# Epoch 36/200... Discriminator Loss: 0.8227... Generator Loss: 2.4799
# Epoch 37/200... Discriminator Loss: 0.8386... Generator Loss: 1.7164
# Epoch 38/200... Discriminator Loss: 1.0199... Generator Loss: 1.5999
# Epoch 39/200... Discriminator Loss: 0.9291... Generator Loss: 1.6800
# Epoch 40/200... Discriminator Loss: 0.9977... Generator Loss: 1.5165
# Epoch 41/200... Discriminator Loss: 0.9522... Generator Loss: 1.8700
# Epoch 42/200... Discriminator Loss: 0.9813... Generator Loss: 1.4075
# Epoch 43/200... Discriminator Loss: 0.8625... Generator Loss: 1.7880
# Epoch 44/200... Discriminator Loss: 0.8384... Generator Loss: 1.8539
# Epoch 45/200... Discriminator Loss: 0.9492... Generator Loss: 1.6987
# Epoch 46/200... Discriminator Loss: 0.8886... Generator Loss: 1.9824
# Epoch 47/200... Discriminator Loss: 1.0305... Generator Loss: 1.5900
# Epoch 48/200... Discriminator Loss: 0.9020... Generator Loss: 1.7303
# Epoch 49/200... Discriminator Loss: 1.1184... Generator Loss: 1.5499
# Epoch 50/200... Discriminator Loss: 0.9380... Generator Loss: 1.5603
# Epoch 51/200... Discriminator Loss: 1.1122... Generator Loss: 1.6434
# Epoch 52/200... Discriminator Loss: 0.9827... Generator Loss: 1.7579
# Epoch 53/200... Discriminator Loss: 0.9528... Generator Loss: 1.5928
# Epoch 54/200... Discriminator Loss: 0.9180... Generator Loss: 1.7650
# Epoch 55/200... Discriminator Loss: 1.1055... Generator Loss: 1.6813
# Epoch 56/200... Discriminator Loss: 0.9708... Generator Loss: 1.7303
# Epoch 57/200... Discriminator Loss: 0.9050... Generator Loss: 1.5369
# Epoch 58/200... Discriminator Loss: 0.9763... Generator Loss: 1.7612
# Epoch 59/200... Discriminator Loss: 1.0406... Generator Loss: 1.2394
# Epoch 60/200... Discriminator Loss: 0.9779... Generator Loss: 1.6316
# Epoch 61/200... Discriminator Loss: 0.9777... Generator Loss: 1.6955
# Epoch 62/200... Discriminator Loss: 0.8852... Generator Loss: 1.7938
# Epoch 63/200... Discriminator Loss: 0.9837... Generator Loss: 1.4491
# Epoch 64/200... Discriminator Loss: 1.0734... Generator Loss: 1.5168
# Epoch 65/200... Discriminator Loss: 0.9628... Generator Loss: 2.1018
# Epoch 66/200... Discriminator Loss: 0.9773... Generator Loss: 1.7325
# Epoch 67/200... Discriminator Loss: 1.1047... Generator Loss: 1.5158
# Epoch 68/200... Discriminator Loss: 0.9175... Generator Loss: 1.5817
# Epoch 69/200... Discriminator Loss: 0.8921... Generator Loss: 2.0026
# Epoch 70/200... Discriminator Loss: 1.0542... Generator Loss: 1.2697
# Epoch 71/200... Discriminator Loss: 0.9658... Generator Loss: 1.9635
# Epoch 72/200... Discriminator Loss: 0.8858... Generator Loss: 1.9500
# Epoch 73/200... Discriminator Loss: 0.9524... Generator Loss: 1.7629
# Epoch 74/200... Discriminator Loss: 1.0090... Generator Loss: 1.4651
# Epoch 75/200... Discriminator Loss: 1.1162... Generator Loss: 1.5158
# Epoch 76/200... Discriminator Loss: 0.9876... Generator Loss: 1.7351
# Epoch 77/200... Discriminator Loss: 1.0436... Generator Loss: 1.5369
# Epoch 78/200... Discriminator Loss: 0.9320... Generator Loss: 1.3846
# Epoch 79/200... Discriminator Loss: 0.9692... Generator Loss: 1.6983
# Epoch 80/200... Discriminator Loss: 1.0153... Generator Loss: 1.4470
# Epoch 81/200... Discriminator Loss: 1.0191... Generator Loss: 1.3618
# Epoch 82/200... Discriminator Loss: 1.0363... Generator Loss: 1.4589
# Epoch 83/200... Discriminator Loss: 0.9503... Generator Loss: 1.9011
# Epoch 84/200... Discriminator Loss: 1.0563... Generator Loss: 1.6309
# Epoch 85/200... Discriminator Loss: 1.0305... Generator Loss: 1.6290
# Epoch 86/200... Discriminator Loss: 0.9416... Generator Loss: 1.7303
# Epoch 87/200... Discriminator Loss: 0.9500... Generator Loss: 1.5770
# Epoch 88/200... Discriminator Loss: 1.0173... Generator Loss: 1.9213
# Epoch 89/200... Discriminator Loss: 1.0747... Generator Loss: 1.4980
# Epoch 90/200... Discriminator Loss: 1.0631... Generator Loss: 1.7393
# Epoch 91/200... Discriminator Loss: 1.2611... Generator Loss: 1.3964
# Epoch 92/200... Discriminator Loss: 0.9165... Generator Loss: 1.6064
# Epoch 93/200... Discriminator Loss: 1.0346... Generator Loss: 1.5740
# Epoch 94/200... Discriminator Loss: 1.0695... Generator Loss: 1.6044
# Epoch 95/200... Discriminator Loss: 1.1766... Generator Loss: 1.4685
# Epoch 96/200... Discriminator Loss: 1.1265... Generator Loss: 1.2260
# Epoch 97/200... Discriminator Loss: 1.1429... Generator Loss: 1.6387
# Epoch 98/200... Discriminator Loss: 1.0919... Generator Loss: 1.3242
# Epoch 99/200... Discriminator Loss: 0.9579... Generator Loss: 1.6402
# Epoch 100/200... Discriminator Loss: 0.9515... Generator Loss: 1.7667
# Epoch 101/200... Discriminator Loss: 0.9719... Generator Loss: 1.4965
# Epoch 102/200... Discriminator Loss: 1.0756... Generator Loss: 1.5344
# Epoch 103/200... Discriminator Loss: 0.9983... Generator Loss: 1.5218
# Epoch 104/200... Discriminator Loss: 0.9661... Generator Loss: 1.6522
# Epoch 105/200... Discriminator Loss: 1.0233... Generator Loss: 1.5349
# Epoch 106/200... Discriminator Loss: 0.9879... Generator Loss: 1.5032
# Epoch 107/200... Discriminator Loss: 0.9993... Generator Loss: 1.8385
# Epoch 108/200... Discriminator Loss: 1.1364... Generator Loss: 1.3357
# Epoch 109/200... Discriminator Loss: 0.9379... Generator Loss: 1.8674
# Epoch 110/200... Discriminator Loss: 1.0251... Generator Loss: 1.5745
# Epoch 111/200... Discriminator Loss: 1.0235... Generator Loss: 1.5146
# Epoch 112/200... Discriminator Loss: 1.1384... Generator Loss: 1.4624
# Epoch 113/200... Discriminator Loss: 1.1494... Generator Loss: 1.4915
# Epoch 114/200... Discriminator Loss: 1.1194... Generator Loss: 1.3163
# Epoch 115/200... Discriminator Loss: 0.9600... Generator Loss: 1.5515
# Epoch 116/200... Discriminator Loss: 1.0944... Generator Loss: 1.5954
# Epoch 117/200... Discriminator Loss: 1.0503... Generator Loss: 1.4273
# Epoch 118/200... Discriminator Loss: 1.0826... Generator Loss: 1.3670
# Epoch 119/200... Discriminator Loss: 1.0407... Generator Loss: 1.5629
# Epoch 120/200... Discriminator Loss: 1.1131... Generator Loss: 1.4152
# Epoch 121/200... Discriminator Loss: 0.9671... Generator Loss: 1.6248
# Epoch 122/200... Discriminator Loss: 1.1819... Generator Loss: 1.4801
# Epoch 123/200... Discriminator Loss: 1.1357... Generator Loss: 1.2363
# Epoch 124/200... Discriminator Loss: 0.9502... Generator Loss: 1.5239
# Epoch 125/200... Discriminator Loss: 1.0220... Generator Loss: 1.4950
# Epoch 126/200... Discriminator Loss: 0.9812... Generator Loss: 1.6636
# Epoch 127/200... Discriminator Loss: 1.0062... Generator Loss: 1.7594
# Epoch 128/200... Discriminator Loss: 1.0305... Generator Loss: 1.7639
# Epoch 129/200... Discriminator Loss: 1.0282... Generator Loss: 1.6803
# Epoch 130/200... Discriminator Loss: 0.9351... Generator Loss: 1.9067
# Epoch 131/200... Discriminator Loss: 1.0494... Generator Loss: 1.3932
# Epoch 132/200... Discriminator Loss: 1.0459... Generator Loss: 1.3912
# Epoch 133/200... Discriminator Loss: 0.9306... Generator Loss: 1.6994
# Epoch 134/200... Discriminator Loss: 1.0938... Generator Loss: 1.3398
# Epoch 135/200... Discriminator Loss: 1.0053... Generator Loss: 1.6683
# Epoch 136/200... Discriminator Loss: 0.9433... Generator Loss: 1.6000
# Epoch 137/200... Discriminator Loss: 0.9292... Generator Loss: 1.4127
# Epoch 138/200... Discriminator Loss: 1.0487... Generator Loss: 1.4494
# Epoch 139/200... Discriminator Loss: 1.0785... Generator Loss: 1.4914
# Epoch 140/200... Discriminator Loss: 1.0023... Generator Loss: 1.6213
# Epoch 141/200... Discriminator Loss: 1.0341... Generator Loss: 1.7192
# Epoch 142/200... Discriminator Loss: 0.9929... Generator Loss: 1.3886
# Epoch 143/200... Discriminator Loss: 1.1028... Generator Loss: 1.3933
# Epoch 144/200... Discriminator Loss: 1.0691... Generator Loss: 1.4665
# Epoch 145/200... Discriminator Loss: 1.1101... Generator Loss: 1.3137
# Epoch 146/200... Discriminator Loss: 1.1296... Generator Loss: 1.4321
# Epoch 147/200... Discriminator Loss: 1.1740... Generator Loss: 1.2769
# Epoch 148/200... Discriminator Loss: 1.1450... Generator Loss: 1.5718
# Epoch 149/200... Discriminator Loss: 1.0263... Generator Loss: 1.6843
# Epoch 150/200... Discriminator Loss: 0.9764... Generator Loss: 1.4548
# Epoch 151/200... Discriminator Loss: 1.0887... Generator Loss: 1.4294
# Epoch 152/200... Discriminator Loss: 1.0824... Generator Loss: 1.5229
# Epoch 153/200... Discriminator Loss: 1.1838... Generator Loss: 1.3053
# Epoch 154/200... Discriminator Loss: 1.0591... Generator Loss: 1.4643
# Epoch 155/200... Discriminator Loss: 1.0945... Generator Loss: 1.6171
# Epoch 156/200... Discriminator Loss: 1.1067... Generator Loss: 1.3694
# Epoch 157/200... Discriminator Loss: 1.0574... Generator Loss: 1.5221
# Epoch 158/200... Discriminator Loss: 0.9980... Generator Loss: 1.7291
# Epoch 159/200... Discriminator Loss: 1.0578... Generator Loss: 1.3915
# Epoch 160/200... Discriminator Loss: 1.0200... Generator Loss: 1.6018
# Epoch 161/200... Discriminator Loss: 0.9377... Generator Loss: 1.6710
# Epoch 162/200... Discriminator Loss: 0.9739... Generator Loss: 1.5461
# Epoch 163/200... Discriminator Loss: 0.9638... Generator Loss: 1.4173
# Epoch 164/200... Discriminator Loss: 1.0534... Generator Loss: 1.6408
# Epoch 165/200... Discriminator Loss: 1.1016... Generator Loss: 1.3787
# Epoch 166/200... Discriminator Loss: 0.8816... Generator Loss: 1.8173
# Epoch 167/200... Discriminator Loss: 1.0520... Generator Loss: 1.4716
# Epoch 168/200... Discriminator Loss: 1.1346... Generator Loss: 1.5071
# Epoch 169/200... Discriminator Loss: 1.0273... Generator Loss: 1.5426
# Epoch 170/200... Discriminator Loss: 1.0968... Generator Loss: 1.4467
# Epoch 171/200... Discriminator Loss: 1.0388... Generator Loss: 1.4859
# Epoch 172/200... Discriminator Loss: 1.1262... Generator Loss: 1.5652
# Epoch 173/200... Discriminator Loss: 1.0460... Generator Loss: 1.4743
# Epoch 174/200... Discriminator Loss: 1.1547... Generator Loss: 1.4489
# Epoch 175/200... Discriminator Loss: 1.0847... Generator Loss: 1.7232
# Epoch 176/200... Discriminator Loss: 1.0338... Generator Loss: 1.7345
# Epoch 177/200... Discriminator Loss: 0.9421... Generator Loss: 1.6632
# Epoch 178/200... Discriminator Loss: 1.0411... Generator Loss: 1.4677
# Epoch 179/200... Discriminator Loss: 1.0455... Generator Loss: 1.7202
# Epoch 180/200... Discriminator Loss: 1.0115... Generator Loss: 1.3771
# Epoch 181/200... Discriminator Loss: 1.0209... Generator Loss: 1.7515
# Epoch 182/200... Discriminator Loss: 1.1322... Generator Loss: 1.3910
# Epoch 183/200... Discriminator Loss: 0.9470... Generator Loss: 1.6886
# Epoch 184/200... Discriminator Loss: 0.9717... Generator Loss: 1.6128
# Epoch 185/200... Discriminator Loss: 1.0263... Generator Loss: 1.4778
# Epoch 186/200... Discriminator Loss: 0.9714... Generator Loss: 1.4923
# Epoch 187/200... Discriminator Loss: 0.9952... Generator Loss: 1.7202
# Epoch 188/200... Discriminator Loss: 0.9819... Generator Loss: 1.5560
# Epoch 189/200... Discriminator Loss: 1.1451... Generator Loss: 1.2749
# Epoch 190/200... Discriminator Loss: 1.0859... Generator Loss: 1.4173
# Epoch 191/200... Discriminator Loss: 0.9196... Generator Loss: 1.6716
# Epoch 192/200... Discriminator Loss: 1.0107... Generator Loss: 1.4389
# Epoch 193/200... Discriminator Loss: 1.0541... Generator Loss: 1.6141
# Epoch 194/200... Discriminator Loss: 1.0160... Generator Loss: 1.7749
# Epoch 195/200... Discriminator Loss: 1.1578... Generator Loss: 1.5234
# Epoch 196/200... Discriminator Loss: 1.1051... Generator Loss: 1.3155
# Epoch 197/200... Discriminator Loss: 1.0422... Generator Loss: 1.6106
# Epoch 198/200... Discriminator Loss: 1.0607... Generator Loss: 1.3539
# Epoch 199/200... Discriminator Loss: 1.1213... Generator Loss: 1.4455
# Epoch 200/200... Discriminator Loss: 0.9138... Generator Loss: 1.6546

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
saver=tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
  saver.restore(sess,tf.train.latest_checkpoint('checkpoints'))
  sample_z=np.random.uniform(-1,1,size=(16,z_size))
  gen_samples=sess.run(generator(input_z,input_size,n_units=g_hidden_size,reuse=True,alpha=alpha),feed_dict={input_z:sample_z})
_=view_samples(0,[gen_samples])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/generator.ckpt
